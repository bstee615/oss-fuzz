# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv("projects_info.csv", index_col=0)

# %%
# from matplotlib import ticker
fig, ax = plt.subplots(1, 2)
sns.histplot(df, x="line_coverage", stat="count", ax=ax[0])
sns.histplot(df, x="line_coverage", stat="percent", ax=ax[1])
plt.tight_layout()
# ax = plt.gca()
# # max_y = 0.8
# # ax.set_ylim([0, int(len(df)*max_y)])  # https://stackoverflow.com/a/25421861
# ax2 = ax.twinx()  # https://stackoverflow.com/a/35073179
# ax2.set_ylim(*ax.get_ylim())  # https://stackoverflow.com/a/15534984
# plt.gca().yaxis.set_major_formatter(ticker.PercentFormatter(xmax=len(df)))  # https://malithjayaweera.com/2018/09/add-matplotlib-percentage-ticks-histogram/
# ax2.yaxis.set_ticks(np.arange(0, len(df)+len(df)/20, len(df)/20))  # https://stackoverflow.com/a/12608937
# ax.set_ylabel("Count")
# ax2.set_ylabel("Percentage")
ax[0].set_xlabel("Line coverage (%)")
ax[1].set_xlabel("Line coverage (%)")
# Out:
# Text(0.5, 23.52222222222222, 'Line coverage (%)')

# %%
print(df.groupby(["project"]).ngroups, "projects")
print("average", round(df.groupby("project")["method"].count().mean(), 1), "methods per project")
print("median", round(df.groupby("project")["method"].count().median(), 1), "methods per project")
print(len(df), "unique methods")
print(str(round((df["num_unique_inputs"] == 1).mean() * 100, 2)) + "%", "have 1 unique input")
print("Frequencies of 1-5 unique inputs")
print(df["num_unique_inputs"].value_counts(normalize=True).sort_index().head(5).apply(lambda f: f"{round(100*f, 2)}%"))

print("Overall stats:")
print(pd.DataFrame((df["line_coverage"].describe(), df["num_unique_inputs"].describe())).to_markdown())

print("Broken down by project (MEAN):")
mean_by_project = df.dropna().groupby("project")[["line_coverage", "num_unique_inputs"]].mean()
t = df.dropna().groupby("project")[["line_coverage", "num_unique_inputs"]].agg(["mean", "count"])
print(t.to_csv())
print("Broken down by project (MEDIAN):")
print(df.dropna().groupby("project")[["line_coverage", "num_unique_inputs"]].median().to_markdown())
# Out:
# 77 projects
# average 34.4 methods per project
# median 19.0 methods per project
# 2649 unique methods
# 93.17% have 1 unique input
# Frequencies of 1-5 unique inputs
# 1    93.17%
# 2     4.53%
# 3     0.34%
# 4     0.23%
# 5     0.11%
# Name: num_unique_inputs, dtype: object
# Overall stats:
# |                   |   count |     mean |       std |   min |      25% |      50% |   75% |   max |
# |:------------------|--------:|---------:|----------:|------:|---------:|---------:|------:|------:|
# | line_coverage     |    2649 | 0.682112 |  0.303622 |     0 | 0.454545 | 0.714286 |     1 |     1 |
# | num_unique_inputs |    2649 | 2.94677  | 47.0981   |     1 | 1        | 1        |     1 |  2046 |
# Broken down by project (MEAN):
# ,line_coverage,line_coverage,num_unique_inputs,num_unique_inputs
# ,mean,count,mean,count
# project,,,,
# angus-mail,0.8202835811531464,9,154.22222222222223,9
# apache-commons,0.7303063436647251,314,1.2802547770700636,314
# apache-commons-bcel,0.5687924342759104,19,1.0,19
# apache-commons-beanutils,0.7292997633836144,14,1.0,14
# apache-commons-cli,0.6711794730729262,41,1.048780487804878,41
# apache-commons-codec,0.585827996575121,19,1.0526315789473684,19
# apache-commons-collections,0.8257936507936509,14,1.0,14
# apache-commons-configuration,0.7793103448275862,29,1.0689655172413792,29
# apache-commons-io,0.7880555555555555,15,1.4666666666666666,15
# apache-commons-lang,0.6487764282501125,15,1.1333333333333333,15
# apache-felix-dev,0.5444373619554974,11,8.272727272727273,11
# archaius-core,0.5660745491178928,50,1.12,50
# aspectj,0.5,1,1.0,1
# bc-java,0.4946483029123351,70,12.6,70
# cglib,0.8252760659819484,75,1.0533333333333332,75
# checker-framework,0.7118720821661998,15,2.2,15
# fastjson2,0.4409924387625481,33,1.0606060606060606,33
# greenmail,0.8186114651631893,29,1.206896551724138,29
# groovy,0.654983660130719,34,1.2352941176470589,34
# guava,0.7182557780466573,159,1.79874213836478,159
# guice,0.7125504756767523,28,1.0357142857142858,28
# h2database,0.6751840048495465,152,1.1644736842105263,152
# hamcrest,0.8573260073260074,26,1.0384615384615385,26
# hdrhistogram,0.7916666666666666,5,1.2,5
# httpcomponents-client,0.6894342684219565,43,1.069767441860465,43
# httpcomponents-core,0.5555555555555555,3,1.0,3
# jackson-core,0.6612683212742307,154,1.0129870129870129,154
# jackson-databind,0.7333333333333333,5,1.8,5
# jackson-dataformat-xml,0.7777777777777777,3,1.0,3
# jackson-dataformats-binary,0.8888888888888888,3,1.0,3
# jackson-dataformats-text,0.7416666666666667,3,1.0,3
# jakarta-mail-api,0.6906918564527259,6,1.0,6
# janino,0.6760366559808583,63,1.0476190476190477,63
# java-example,0.6607142857142857,4,1.75,4
# javaparser,0.6410256410256411,13,1.0,13
# javassist,0.6071127946127945,18,1.5555555555555556,18
# jaxb,0.5260868924407811,14,1.0714285714285714,14
# jersey,0.49761069546395637,20,1.0,20
# jettison,0.6834249084249083,7,1.4285714285714286,7
# jimfs,0.7265493122937096,59,1.0338983050847457,59
# jmh,0.9120370370370371,24,1.0,24
# joda-time,0.6110000542705146,34,2.1176470588235294,34
# jsign,0.8468537414965986,7,4.0,7
# json-java,0.6204209245875912,24,1.0416666666666667,24
# json-sanitizer,0.720794779585331,25,1.12,25
# jsoup,0.7726107804232805,24,1.0416666666666667,24
# jul-to-slf4j,1.0,3,1.3333333333333333,3
# junrar,0.6482955155076225,33,1.2121212121212122,33
# kryo,0.763764397069946,39,1.0256410256410255,39
# log4j2,0.5962710693647513,81,1.1358024691358024,81
# logback,0.47304328874406903,98,1.0204081632653061,98
# maven,0.5534897876541514,15,1.0,15
# okhttp,0.7934782608695652,4,1.0,4
# osgi,0.640253856363482,22,1.0,22
# plexus-utils,0.617846331647759,39,4.282051282051282,39
# protobuf-java,0.7629397373962591,12,1.0,12
# reload4j,0.6818978419664918,39,1.0,39
# rxjava,0.7306595365418894,6,1.0,6
# servo-core,0.45833333333333337,2,1.5,2
# slf4j-api,0.6582378405907818,15,1.0,15
# snakeyaml,0.7887950107579264,46,1.1521739130434783,46
# spring-amqp,0.9093230312492607,28,1.0,28
# spring-boot,0.7066936902966315,20,1.1,20
# spring-cloud-commons,0.3333333333333333,1,2.0,1
# spring-data-jpa,0.4357142857142857,2,1.5,2
# spring-data-mongodb,0.4862471753370195,14,1.6428571428571428,14
# spring-data-redis,0.9705882352941175,2,2.0,2
# spring-ldap,0.8344556677890012,18,1.0,18
# spring-retry,0.5842424242424243,2,1024.0,2
# spring-security,0.7997715707217758,63,2.7142857142857144,63
# spring-shell,0.3143939393939394,4,1.0,4
# stringtemplate4,0.5711550245098039,8,1.0,8
# tomcat,0.6339742727388177,150,2.066666666666667,150
# woodstox,0.575269378926316,17,1.0,17
# xmlpull,0.6537797508940683,6,1.1666666666666667,6
# xstream,0.7390075899651359,51,1.0392156862745099,51
# zip4j,0.7555483691203356,76,1.0,76
#
# Broken down by project (MEDIAN):
# | project                      |   line_coverage |   num_unique_inputs |
# |:-----------------------------|----------------:|--------------------:|
# | angus-mail                   |        0.869565 |                55   |
# | apache-commons               |        0.777778 |                 1   |
# | apache-commons-bcel          |        0.666667 |                 1   |
# | apache-commons-beanutils     |        0.683333 |                 1   |
# | apache-commons-cli           |        0.666667 |                 1   |
# | apache-commons-codec         |        0.666667 |                 1   |
# | apache-commons-collections   |        1        |                 1   |
# | apache-commons-configuration |        1        |                 1   |
# | apache-commons-io            |        0.875    |                 1   |
# | apache-commons-lang          |        0.684211 |                 1   |
# | apache-felix-dev             |        0.642857 |                 1   |
# | archaius-core                |        0.6      |                 1   |
# | aspectj                      |        0.5      |                 1   |
# | bc-java                      |        0.422222 |                 1   |
# | cglib                        |        1        |                 1   |
# | checker-framework            |        0.75     |                 1   |
# | fastjson2                    |        0.333333 |                 1   |
# | greenmail                    |        0.846154 |                 1   |
# | groovy                       |        0.666667 |                 1   |
# | guava                        |        0.75     |                 1   |
# | guice                        |        0.845238 |                 1   |
# | h2database                   |        0.732057 |                 1   |
# | hamcrest                     |        1        |                 1   |
# | hdrhistogram                 |        0.875    |                 1   |
# | httpcomponents-client        |        0.666667 |                 1   |
# | httpcomponents-core          |        0.5      |                 1   |
# | jackson-core                 |        0.666667 |                 1   |
# | jackson-databind             |        0.666667 |                 1   |
# | jackson-dataformat-xml       |        0.666667 |                 1   |
# | jackson-dataformats-binary   |        1        |                 1   |
# | jackson-dataformats-text     |        0.8      |                 1   |
# | jakarta-mail-api             |        0.755952 |                 1   |
# | janino                       |        0.75     |                 1   |
# | java-example                 |        0.75     |                 2   |
# | javaparser                   |        0.666667 |                 1   |
# | javassist                    |        0.651515 |                 1   |
# | jaxb                         |        0.445652 |                 1   |
# | jersey                       |        0.5      |                 1   |
# | jettison                     |        0.666667 |                 1   |
# | jimfs                        |        0.75     |                 1   |
# | jmh                          |        1        |                 1   |
# | joda-time                    |        0.645833 |                 1   |
# | jsign                        |        1        |                 1   |
# | json-java                    |        0.641026 |                 1   |
# | json-sanitizer               |        0.875    |                 1   |
# | jsoup                        |        1        |                 1   |
# | jul-to-slf4j                 |        1        |                 1   |
# | junrar                       |        0.714286 |                 1   |
# | kryo                         |        0.888889 |                 1   |
# | log4j2                       |        0.5      |                 1   |
# | logback                      |        0.354167 |                 1   |
# | maven                        |        0.5      |                 1   |
# | okhttp                       |        1        |                 1   |
# | osgi                         |        0.651515 |                 1   |
# | plexus-utils                 |        0.666667 |                 1   |
# | protobuf-java                |        0.875    |                 1   |
# | reload4j                     |        0.75     |                 1   |
# | rxjava                       |        0.75     |                 1   |
# | servo-core                   |        0.458333 |                 1.5 |
# | slf4j-api                    |        0.642857 |                 1   |
# | snakeyaml                    |        1        |                 1   |
# | spring-amqp                  |        1        |                 1   |
# | spring-boot                  |        0.686275 |                 1   |
# | spring-cloud-commons         |        0.333333 |                 2   |
# | spring-data-jpa              |        0.435714 |                 1.5 |
# | spring-data-mongodb          |        0.380556 |                 1   |
# | spring-data-redis            |        0.970588 |                 2   |
# | spring-ldap                  |        1        |                 1   |
# | spring-retry                 |        0.584242 |              1024   |
# | spring-security              |        0.83871  |                 1   |
# | spring-shell                 |        0.333333 |                 1   |
# | stringtemplate4              |        0.421875 |                 1   |
# | tomcat                       |        0.72381  |                 1   |
# | woodstox                     |        0.571429 |                 1   |
# | xmlpull                      |        0.735849 |                 1   |
# | xstream                      |        0.857143 |                 1   |
# | zip4j                        |        0.975    |                 1   |

# %%
sns.histplot(mean_by_project, x="line_coverage")
plt.xlabel("Mean function-level line coverage by project")
# Out:
# Text(0.5, 0, 'Mean function-level line coverage by project')

# %%
sns.histplot(mean_by_project, x="num_unique_inputs", bins=50)
plt.xlabel("Mean unique function-level inputs by project")
# Out:
# Text(0.5, 0, 'Mean unique function-level inputs by project')

# %%
sns.histplot(df, x="line_coverage")
# Out:
# <AxesSubplot: xlabel='line_coverage', ylabel='Count'>

# %%
sns.histplot(df.groupby("project")["method"].count())
plt.xlabel("# methods")
# Out:
# Text(0.5, 0, '# methods')

# %%
data = []
with open("fuzzed_input_counts.txt") as f:
    for line in f:
        project, fuzzer, count = line.split()
        fuzzer = fuzzer[len("address-x86_64-"):]
        data.append({
            "project": project,
            "fuzzer": fuzzer,
            "count": int(count),
        })
fdf = pd.DataFrame(data)
fdf
# Out:
#             project                     fuzzer  count
# 0        angus-mail         ASCIIUtilityFuzzer     54
# 1        angus-mail  BASE64EncoderStreamFuzzer    104
# 2       antlr4-java              GrammarFuzzer      0
# 3    apache-commons       CompressSevenZFuzzer    501
# 4    apache-commons          CompressTarFuzzer   7878
# ..              ...                        ...    ...
# 206          tomcat           WsPingPongFuzzer   1420
# 207        woodstox                  XmlFuzzer    814
# 208         xmlpull    PullParserFactoryFuzzer     15
# 209         xstream                  XmlFuzzer  11400
# 210           zip4j                Zip4jFuzzer   4711
#
# [211 rows x 3 columns]

# %%
sns.histplot(fdf, x="count")
# plt.xscale("log")
plt.xlabel("# fuzzer inputs")
plt.ylabel("# fuzzer targets")
# Out:
# Text(0, 0.5, '# fuzzer targets')

# %%
sns.histplot(fdf.groupby("project")["count"].sum())
# plt.xscale("log")
plt.xlabel("# fuzzer inputs")
plt.ylabel("# projects")
# Out:
# Text(0, 0.5, '# projects')

# %%
mdf = df.dropna()
mean_stats = mdf.groupby("project")[["line_coverage", "num_unique_inputs"]].mean()
counts = mdf.groupby("project")["line_coverage"].count().rename("function_count")
project_fuzzedinput_counts = fdf.groupby("project")["count"].sum().rename("input_count")
rdf = mean_stats.join(counts).join(project_fuzzedinput_counts).reset_index()
# rdf = pd.melt(rdf, id_vars="project", var_name="stat", value_name="value")
# rdf = rdf.sort_values(["project", "stat"])
# rdf["value"] = rdf["value"].astype(float)
# sns.barplot(x='project', y='value', hue='stat', data=rdf)
rdf.to_clipboard()
rdf
# Out:
#                      project  line_coverage  num_unique_inputs  \
# 0                 angus-mail       0.820284         154.222222
# 1             apache-commons       0.730306           1.280255
# 2        apache-commons-bcel       0.568792           1.000000
# 3   apache-commons-beanutils       0.729300           1.000000
# 4         apache-commons-cli       0.671179           1.048780
# ..                       ...            ...                ...
# 72                    tomcat       0.633974           2.066667
# 73                  woodstox       0.575269           1.000000
# 74                   xmlpull       0.653780           1.166667
# 75                   xstream       0.739008           1.039216
# 76                     zip4j       0.755548           1.000000
#
#     function_count  input_count
# 0                9          158
# 1              314        18078
# 2               19          351
# 3               14         7145
# 4               41         1615
# ..             ...          ...
# 72             150        68601
# 73              17          814
# 74               6           15
# 75              51        11400
# 76              76         4711
#
# [77 rows x 5 columns]

# %%
sns.scatterplot(data=rdf, x="line_coverage", y="num_unique_inputs")
plt.xlabel("Line coverage (%)")
plt.ylabel("# unique function-level inputs")
# Out:
# Text(0, 0.5, '# unique function-level inputs')

# %%
sns.scatterplot(data=rdf, x="line_coverage", y="input_count")
plt.xlabel("Line coverage (%)")
plt.ylabel("# fuzzer inputs")
# Out:
# Text(0, 0.5, '# fuzzer inputs')

# %%
sns.scatterplot(data=rdf, x="line_coverage", y="function_count")
plt.xlabel("Line coverage (%)")
plt.ylabel("# functions")
# Out:
# Text(0, 0.5, '# functions')

# %%
sns.scatterplot(data=rdf, x="num_unique_inputs", y="num_unique_inputs")
plt.xlabel("# unique function-level inputs")
plt.ylabel("# unique function-level inputs")
# Out:
# Text(0, 0.5, '# unique function-level inputs')

# %%
sns.scatterplot(data=rdf, x="num_unique_inputs", y="input_count")
plt.xlabel("# unique function-level inputs")
plt.ylabel("# fuzzer inputs")
# Out:
# Text(0, 0.5, '# fuzzer inputs')

# %%
sns.scatterplot(data=rdf, x="num_unique_inputs", y="function_count")
plt.xlabel("# unique function-level inputs")
plt.ylabel("# functions")
# Out:
# Text(0, 0.5, '# functions')

# %%
df
# Out:
#          project                                       class  \
# 0     angus-mail                          ASCIIUtilityFuzzer
# 1     angus-mail                   BASE64EncoderStreamFuzzer
# 2     angus-mail              com.sun.mail.util.ASCIIUtility
# 3     angus-mail              com.sun.mail.util.ASCIIUtility
# 4     angus-mail              com.sun.mail.util.ASCIIUtility
# ...          ...                                         ...
# 2644       zip4j  net.lingala.zip4j.crypto.StandardDecrypter
# 2645       zip4j     net.lingala.zip4j.model.ExtraDataRecord
# 2646       zip4j  net.lingala.zip4j.model.AbstractFileHeader
# 2647       zip4j   net.lingala.zip4j.model.Zip64ExtendedInfo
# 2648       zip4j   net.lingala.zip4j.model.Zip64ExtendedInfo
#
#                     method  start_line  line_coverage  num_unique_inputs
# 0       fuzzerTestOneInput          24       1.000000                  2
# 1       fuzzerTestOneInput          25       0.800000                  2
# 2                 parseInt          43       0.939394                 55
# 3                parseLong         133       0.787879                 35
# 4                 toString         219       1.000000                 55
# ...                    ...         ...            ...                ...
# 2644                  init          50       0.153846                  1
# 2645               setData          45       1.000000                  1
# 2646  setZip64ExtendedInfo         142       1.000000                  1
# 2647     setCompressedSize          46       1.000000                  1
# 2648   setUncompressedSize          54       1.000000                  1
#
# [2649 rows x 6 columns]

# %% [markdown]
# # Loaded data from processing all
# Looking at examples with only 1 function-level input

# %%
df[df["num_unique_inputs"] == 1]
# Out:
#              project                                              class  \
# 9     apache-commons                               CompressSevenZFuzzer
# 10    apache-commons  org.apache.commons.compress.archivers.sevenz.S...
# 11    apache-commons  org.apache.commons.compress.utils.SeekableInMe...
# 12    apache-commons  org.apache.commons.compress.utils.SeekableInMe...
# 13    apache-commons          org.apache.commons.compress.utils.IOUtils
# ...              ...                                                ...
# 2644           zip4j         net.lingala.zip4j.crypto.StandardDecrypter
# 2645           zip4j            net.lingala.zip4j.model.ExtraDataRecord
# 2646           zip4j         net.lingala.zip4j.model.AbstractFileHeader
# 2647           zip4j          net.lingala.zip4j.model.Zip64ExtendedInfo
# 2648           zip4j          net.lingala.zip4j.model.Zip64ExtendedInfo
#
#                     method  start_line  line_coverage  num_unique_inputs
# 9         fuzzerInitialize          29       1.000000                  1
# 10             utf16Decode        2057       0.250000                  1
# 11              ensureOpen         209       0.500000                  1
# 12                    read         133       0.800000                  1
# 13               readFully         222       0.777778                  1
# ...                    ...         ...            ...                ...
# 2644                  init          50       0.153846                  1
# 2645               setData          45       1.000000                  1
# 2646  setZip64ExtendedInfo         142       1.000000                  1
# 2647     setCompressedSize          46       1.000000                  1
# 2648   setUncompressedSize          54       1.000000                  1
#
# [2468 rows x 6 columns]

# %%
import jsonlines
import tqdm
import itertools
import numpy as np
import json
from dataclasses import dataclass, field
from typing import List, Set, Tuple, Union

@dataclass
class Stats:
    coverage: List[Set[int]] = field(default_factory=list)
    code: str = None
    key: Tuple[Union[str, int]] = None
    inputs: List = field(default_factory=list)

    @property
    def unique_functions(self):
        return len(set(map(str, self.inputs)))

    def add_input(self, inp):
        self.inputs.append(inp)

    def add_code(self, example):
        if self.code is None:
            self.code = example["code"]

    def add_coverage(self, example):
        self.coverage.append(set(s["relative_lineno"] for s in example["lines_covered"]))
    
    def calculate_line_coverage(self):
        should_be_covered = get_all_lines_in_code(self.code)
        lines_code = self.code.splitlines()
        exclude_lines = set(i for i, l in enumerate(lines_code, start=1) if l.strip() == "}" or (l.strip().startswith("catch") and l.strip().endswith("{")))
        new_coverage = []
        if len(self.coverage) == 0:
            self.coverage = []
            all_covered_lines = set()
        else:
            for cs in self.coverage:
                cs = set(x for x in cs if x not in exclude_lines and x >= 0 and x <= len(lines_code))
                new_coverage.append(cs)
            self.coverage = new_coverage
            all_covered_lines = set.union(*self.coverage)

        intersection = set(l for l in all_covered_lines if any(a <= l <= b for a, b in should_be_covered))
        difference = all_covered_lines.difference(intersection)
        difference = sorted(difference)
        covered = set((a, b) for a, b in should_be_covered if any(a <= l <= b for l in all_covered_lines))
        not_covered = set((a, b) for a, b in should_be_covered if not any(a <= l <= b for l in all_covered_lines))
        not_covered_start = [x[0] if x[0] == x[1] else x for x in sorted(not_covered)]

        line_coverage = (len(covered) / len(should_be_covered)) if len(should_be_covered) > 0 else 1.0

        if (debug and (select_key is None or self.key == select_key)):
            print("KEY:", self.key)
            print("EXPORT STATS")
            # print("TRACED", stats.coverage)
            # print("TRACED (UNION)", list(sorted(all_covered_lines)))
            print("EXECUTABLE:", list(sorted(should_be_covered)))
            print("INTERSECTION:", list(sorted(covered)))
            print("LINE COVERAGE:", line_coverage*100 , "%")
            if len(not_covered) > 0:
                print("NOT COVERED:", not_covered)
            if len(difference) > 0:
                print("TRACED NOT IN EXECUTABLE:", difference)
            print("CODE:")
            print(
                "\n".join(str(i).rjust(3, " ") + " "
                + l +
                (" // NOT COVERED" if i in not_covered_start else "") +
                (" // NOT PARSED" if i in difference else "")
                for i, l in enumerate(self.code.splitlines(), start=1)))
            print("TREE:")
            print_tree(parser.parse(self.code.encode()).root_node)

        # if len(difference) > 0:
        #     print("KEY:", self.key)
        #     print("COVERED:", all_covered_lines)
        #     print("SHOULD BE:", should_be_covered)
        #     print("CODE:")
        #     print(
        #         "\n".join(str(i).rjust(3, " ") + " "
        #         + l +
        #         (" // NOT PARSED" if i in difference else "")
        #         for i, l in enumerate(self.code.splitlines(), start=1)))
        #     print("TREE:")
        #     print_tree(parser.parse(self.code.encode()).root_node)
            # assert len(difference) == 0, (difference)
        return line_coverage

def has_ancestor(n, fn):
    # print("SEARCHING FOR =")
    # print_node(n)
    q = [n]
    while len(q) > 0:
        n = q.pop()
        # print("\t", end="")
        # print_node(n)
        if fn(n):
            return True
        q.extend(reversed(n.children))
    return False

def get_all_lines_in_code(code):
    tree = parser.parse(("public class Foo{" + code + "}").encode())
    # print_tree(tree.root_node)
    traceable_lines = []
    q = [tree.root_node]
    while len(q) > 0:
        n = q.pop()
        if n.type == "method_declaration":
            block = next((c for c in n.children if c.type == "block"), None)
            if block is None:
                print("block is missing:")
                print(code)
                continue
            if not any(c.is_named for c in block.children):
                traceable_lines.append(block)
        if (
            n.type.endswith("_statement")
            or n.type in ("switch_expression",)
            or (n.type == "local_variable_declaration" and has_ancestor(n, lambda n: n.type == "="))
            # or (n.type == "}" and n.parent.parent.type == "method_declaration")
            ):
            # print("EXECUTABLE STATEMENT:", end="")
            # print_node(n)
            # print_node(n.parent)
            traceable_lines.append(n)
        # else:
        q.extend(reversed(n.children))
    
    should_be_covered = set((n.start_point[0]+1, n.end_point[0]+1) for n in traceable_lines)
    return should_be_covered

# debug = True
debug = False
select_key = None
# select_key = ('apache-commons', 'org.apache.commons.compress.archivers.zip.NioZipEncoding', 'newDecoder', 176)

function_idx = 0
current_key = None
current_stats = Stats()
all_line_coverage = {}
# fname = "postprocessed_runall_checkmethod/postprocessed_dedup_sort_filter.jsonl"
fname = "postprocessed_test_init_dedup_sort_filter.jsonl"
num_lines = 0
failed_examples = 0
projects = set()
keys = set()
with open(fname) as f:
    for line in tqdm.tqdm(f, desc="count lines"):
        num_lines += 1
with jsonlines.open(fname) as reader, jsonlines.open("failed_assert.jsonl", "w") as writer:
    pbar = tqdm.tqdm(reader, total=num_lines, desc="calculate stats")
    for example in pbar:
        key = (example["project"], example["class"], example["method"], example["start_point"][0]+1)
        projects.add(example["project"])
        keys.add(key)
        # if example["code"] is None:
        #     print("No code:", key)
        #     continue
        try:
            if current_key is None:
                current_key = key
                current_stats.key = key
            if key != current_key:
                all_line_coverage[current_stats.key] = (current_stats.calculate_line_coverage(), current_stats.unique_functions)
                current_stats = Stats()
                current_key = key
                current_stats.key = key
            current_stats.add_coverage(example)
            current_stats.add_code(example)
            current_stats.add_input(example["entry_variables"])
        except AssertionError:
            # print("ERROR IN", example["xml_file_path"])
            writer.write(example)
            failed_examples += 1
            pass
            # print(json.dumps(example, indent=2))
            # raise
        pbar.set_description(f"{failed_examples} failed, {len(projects)} projects seen, {len(keys)} keys seen")
    try:
        all_line_coverage[current_stats.key] = (current_stats.calculate_line_coverage(), current_stats.unique_functions)
    except AssertionError:
        writer.write(example)
# Out:
# count lines: 12it [00:00, 64198.53it/s]
# count lines: 12it [00:00, 64198.53it/s]   0%|          | 0/12 [00:00<?, ?it/s]
# 0 failed, 1 projects seen, 1 keys seen: 100%|██████████| 12/12 [00:00<00:00, 1133.11it/s]

# %% [markdown]
# # Loaded data from processing only one method
# This is because there are actually 12 unique inputs to this method

# %%
df = pd.DataFrame(data=[{
    "project": p,
    "class": c,
    "method": m,
    "start_line": l,
    "line_coverage": cov,
    "num_unique_inputs": funcs,
} for (p, c, m, l), (cov, funcs) in all_line_coverage.items()])
df
# Out:
#   project                                       class method  start_line  \
# 0   zip4j  net.lingala.zip4j.crypto.StandardDecrypter   init          50
#
#    line_coverage  num_unique_inputs
# 0       0.153846                 12
